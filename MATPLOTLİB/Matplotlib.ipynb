# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## LİNE PLOT

# %%
x = [1,2,3,4,5]

# %%
y = [6,7,8,9,10]

# %%
a = plt.plot(x,y)
# plot fonksiyonu grafik çizdiren fonk

# %%
plt.show(a)

# %% [markdown]
# ## BAR PLOT

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## HİSTOGRAM

# %%
plt.hist(y)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([ 6. ,  6.4,  6.8,  7.2,  7.6,  8. ,  8.4,  8.8,  9.2,  9.6, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
# it counts the frequency of data

# %% [markdown]
# ## SCATTER PLOT

# %%
plt.scatter(x,y)

# %%
# scatter dağılım demek ve scatter plot bize verilerin grup içerisinde nasıl dağıldığını gösterir

# %% [markdown]
# ## FUNCTİONAL PLOTTİNG

# %%
import numpy as np

# %%
x = np.linspace(0,10,20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y = x**2

# %%
plt.plot(x,y)

# %%
# if you want you can give a name for graphic and axis

# %% [markdown]
# plt.title("BENİM İLK GRAFİĞİM")
# plt.xlabel("x ekseni")
# plt.ylabel("y ekseni")
# plt.plot(x,y)

# %% [markdown]
# ## SUBPLOT() METHOD

# %%
# CREAT MULTİ PLOTS ON THE SAME FİGURE USİNG THE .subplot() method. this method takes 3 parameters:
# nrows = number of rows
# ncols = number of columns
# plot_number = which refers to a specific plot in the figure

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"green")
plt.subplot(1,2,2)
plt.plot(y,x,"red")

# %%
# matplotlib has object oriented interface

# %%
a = plt.figure()#boş bir figure oluşturduk çünkü giving this plot as an object and use its properties and methods to change what is inside

# %%
a.add_axes([0.1, 0.2, 0.8, 0.9])
# Out:
# <Axes: >

# %%
a

# %%
#figure in figure

# %%
fig1 = plt.figure()
axes1 = fig1.add_axes([0.1, 0.2, 0.8, 0.8])
axes2 = fig1.add_axes([0.2, 0.5, 0.4, 0.4])
axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig1.savefig("myfigure.png")
# saving figure

# %%
import matplotlib.image as mpimg
plt.imshow(mpimg.imread("myfigure.png"))
#kaydettigin figureyi geri çağırma yada okuma

# %% [markdown]
# ## CHANGİNG SİZE AND RESOLUTION

# %%
a = plt.figure( figsize=(8,2), dpi=100 )

# %%
ax = a.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,ax = plt.subplot(2,1,1, figsize=(8,4), dpi=100)
ax[0].plot(x,y)
ax[1].ploy(y,x)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 fig,ax = plt.subplot(2,1,1, figsize=(8,4), dpi=100)
#       2 ax[0].plot(x,y)
#       3 ax[1].ploy(y,x)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1311, in subplot(*args, **kwargs)
#    1308             break
#    1309 else:
#    1310     # we have exhausted the known Axes and none match, make a new one!
# -> 1311     ax = fig.add_subplot(*args, **kwargs)
#    1313 fig.sca(ax)
#    1315 axes_to_delete = [other for other in fig.axes
#    1316                   if other != ax and ax.bbox.fully_overlaps(other.bbox)]
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:743, in FigureBase.add_subplot(self, *args, **kwargs)
#     740         args = tuple(map(int, str(args[0])))
#     741     projection_class, pkw = self._process_projection_requirements(
# ...

# %% [markdown]
# ## LEGEND

# %%
fig = plt.figure(figsize(8,6), dpi=100)
ax=fig.add_axes[0,0,1,1]
ax.plot(x,x**2, "green", label= "x square")
ax.plot(x,x**3, "red", label="x cube" )
ax.legend()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 ax.plt.plot(x,y)
#
# AttributeError: 'Axes' object has no attribute 'plt'
